# %% [markdown]
# # Manejo de Excepciones y Calidad de Código

# %% [markdown]
# ### 1. ¿Qué son las excepciones?

# %% [markdown]
# Python utiliza un tipo de objeto especial denominado excepción para gestionar los errores que surgen durante la ejecución de un programa.
#
# Cada vez que ocurre un error que hace que Python no sepa qué hacer a continuación, crea un objeto de excepción. Si se escribe código que maneja la excepción, el programa continuará ejecutándose. Por el contrario, si no se maneja la excepción, el programa se detendrá y mostrará un pequeño resumen de la excepción que se ha producido.
#
# Las excepciones se pueden manejan a través de las sentencias `try` y `except`.

# %%
print(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7081/2734745701.py in <cell line: 0>()
# ----> 1 print(var)
#
# NameError: name 'var' is not defined

# %% [markdown]
# ### 2. Errores de sintaxis vs Excepciones

# %% [markdown]
# A pesar de que en muchas ocasiones estos dos términos se utilizan de manera indistinta cuando hablamos de Python, debemos tener cuidado porque son cosas diferentes.
#
# Los **errores de sintaxis** se producen cuando escribimos una sentencia de código en Python que no es sintácticamente válida. El intérprete de Python indica estos error con el término `SyntaxError` y nos señala con el carácter `^` donde se encuentra el error.

# %%
print("Hola mundo)

# %% [markdown]
# Por otro lado, las **excepciones** se corresponden con errores que se producen en sentencias de código en Python que son sintácticamente correctas. Esto tipo de errores no son fatales para el programa y pueden ser gestionados o ignorados.

# %%
print(var)

# %%
50/0

# %%
'2' + 2

# %% [markdown]
# ### 3. Gestión de excepciones: Sentencias `try` y `except`

# %% [markdown]
# Las sentencias `try` y `except` en Python pueden utilizarse para capturar y manejar excepciones. Python ejecuta el código que sigue a la sentencia `try` como una parte "normal" del programa. El código que sigue a la sentencia `except` se ejecutará si se produce cualquier excepción en la cláusula `try` precedente.
#
# La sintaxis que se utiliza para definir este tipo de comportamiento es la siguiente:
# ```
# try:
#     <sentencia(s)>
# except <excepción>:
#     <sentencias(s) si excepción>
# ```

# %%
print(var)

# %%
try:
    print(var)
except NameError:
    var = "Hola mundo"

# %%
print(var)

# %% [markdown]
# Debemos tener en cuenta que el las sentencias de código que se encuentren en el cuerpo de la sentencia `try` y a continuación de la sentencia que emite la excepción, no se ejecutarán

# %%
print("Sentencias de codigo antes del try")

try:
    print("Codigo antes de la excepcion")
    10 + "3"
    print("Codigo despues de la excepcion")
except TypeError:
    print("No se puede sumar un numero entero y un string")

print("Sentencias de codigo despues del except")
# Out:
# Sentencias de codigo antes del try
# Codigo antes de la excepcion
# No se puede sumar un numero entero y un string
# Sentencias de codigo despues del except

# %% [markdown]
# También podemos utilizar la sentencia `except` sin indicarle el nombre de ninguna excepción, en estos casos capturará todas las excepciones que se produzcan en el código que se encuentra en el cuerpo de la sentencia `try`

# %%
try:
    10 + "3"
except:
    print("No se puede sumar un entero y un string")

# %% [markdown]
# Adicionalmente a la sintaxis anterior, podemos capturar varias excepciones de manera simultánea utilizando varias cláusulas `except`

# %%
try:
    50/0
except NameError:
    print("Gestionando excepcion NameError")
except TypeError:
    print("Gestionando execpcion Type Error")
except ZeroDivisionError:
    print("No puedes dividir un numero por 0")

# %% [markdown]
# Por último, podemos asignar el objeto excepción capturado a una variable y utilizarlos para mostrar más información al respecto.

# %%
try:
    print(variable)
except NameError as error:
    print("Objeto de tipo:", type(error))
    print("La excepcion consiste en:", error)

# %% [markdown]
# ### 4. Lanzando excepciones personalizadas

# %% [markdown]
# Además de las sentencias anteriores que podemos utilizar para controlar excepciones, Python nos proporciona la sentencia `raise` con la que podemos emitir nuestras propias excepciones. Para ello, debemos utilizar la clase por defecto de Python `Exception`

# %%
help(Exception)
# Out:
# Help on class Exception in module builtins:
#
# class Exception(BaseException)
#  |  Common base class for all non-exit exceptions.
#  |
#  |  Method resolution order:
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Built-in subclasses:
#  |      ArithmeticError
#  |      AssertionError
#  |      AttributeError
#  |      BufferError
#  |      ... and 16 other subclasses
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
# ...

# %%
colores_permitidos = ("azul", "verde", "rojo")

color = "amarillo"

if color not in colores_permitidos:
    raise Exception(f"El color {color} no se encuentra en la lista de colores permitidos")

# %%
colores_permitidos = ("azul", "verde", "rojo")

color = "verde"

if color not in colores_permitidos:
    raise Exception(f"El color {color} no se encuentra en la lista de colores permitidos")

# %% [markdown]
# ### 5. Cláusula `else` en excepciones

# %% [markdown]
# Curiosamente, Python nos proporciona un mecanismo por el cual utilizando la sentencia `else`, se puede indicar a un programa que ejecute un determinado bloque de código sólo en ausencia de excepciones.

# %%
try:
    print(variable2)
except NameError:
    print("variable2 no estaba definida, se define con la cadena 'Hola mundo'")
    variable2 = 'Hola mundo'
else:
    print(f"variable2 ya estaba definida con el valor:{variable2}")

# %% [markdown]
# ### 6. Sentencia `finally`

# %% [markdown]
# Python nos proporciona una última sentencia que podemos utilizar para realizar una "limpieza" después de la ejecución de nuestro código al gestionar una excepción. Esta sentencia se denomina `finally` y el código que se localice en su cuerpo, se ejcutará siempre, independientemente de si se produce o no la expcepción.

# %%
try:
    print(variable3)
except NameError:
    print("variable3 no estaba definida, se define con la cadena 'Hola mundo'")
    variable3 = 'Hola mundo'
else:
    print("variable3 ya estaba definida con el valor:", variable2)

# %%
try:
    print(variable3)
except NameError:
    print("variable3 no estaba definida, se define con la cadena 'Hola mundo'")
    variable3 = 'Hola mundo'
else:
    print("variable3 ya estaba definida con el valor:", variable2)
finally:
    del variable3

# %% [markdown]
# ### 7. AssertionError
# La sentencia `assert` es una herramienta de depuración que verifica si una condición es verdadera. Si la condición es falsa, `assert` genera una excepción `AssertionError`. Opcionalmente, se le puede pasar un mensaje de error como segundo argumento que se mostrará si la aserción falla.
#
# Es útil para:
# - **Detectar errores tempranamente:** Asegura que ciertas condiciones se cumplan en puntos específicos del código.
# - **Documentación:** Sirve como una forma de documentar supuestos sobre el estado del programa.
#
# **Sintaxis:**
# ```python
# assert condicion, "Mensaje de error opcional"
# ```
#
# **Ejemplo:**
# ```python
# def dividir(a, b):
#     assert b != 0, "El divisor no puede ser cero"
#     return a / b
#
# # Esto funcionará
# print(dividir(10, 2))
#
# # Esto lanzará un AssertionError
# # print(dividir(10, 0))
# ```

# %%
passwd = input("Introduce una contrasena de mas de 8 digitos:")

assert len(passwd) > 8, "La contrasena es menor a 8 digitos"
# Out:
# Introduce una contrasena de mas de 8 digitos:ana
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_15315/2951652685.py in <cell line: 0>()
#       1 passwd = input("Introduce una contrasena de mas de 8 digitos:")
#       2
# ----> 3 assert len(passwd) > 8, "La contrasena es menor a 8 digitos"
#
# AssertionError: La contrasena es menor a 8 digitos

# %% [markdown]
# ### 8. El módulo `logging`
#
# El módulo `logging` en Python es una herramienta poderosa y flexible para registrar eventos que ocurren durante la ejecución de un programa. Permite a los desarrolladores y operadores monitorear el comportamiento de las aplicaciones, diagnosticar problemas y comprender el flujo de ejecución.
#
# **Beneficios clave:**
# - **Flexibilidad:** Permite configurar dónde se envían los mensajes (consola, archivo, red, etc.), qué nivel de severidad tienen y cómo se formatean.
# - **Severidad:** Define diferentes niveles de mensaje (DEBUG, INFO, WARNING, ERROR, CRITICAL) para categorizar la importancia de los eventos.
# - **No intrusivo:** A diferencia de `print()`, el `logging` se puede habilitar o deshabilitar fácilmente sin modificar el código fuente.
# - **Manejo de errores:** Es esencial para la depuración y para entender por qué una aplicación falla en entornos de producción.
#
# **Componentes principales:**
# - **Loggers:** Los objetos que las aplicaciones usan para hacer llamadas al registro.
# - **Handlers:** Envían los registros (creados por loggers) al destino apropiado (consola, archivo, etc.).
# - **Formatters:** Especifican el formato final de los registros.
# - **Filters:** Proporcionan un control más fino sobre qué registros pasan a través de los handlers.
#
# **Sintaxis básica:**
# Para empezar a usar `logging`, solo necesitas importarlo y usar una de las funciones de nivel de registro predefinidas.
#
# ```python
# import logging
#
# logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
#
# logging.debug('Este es un mensaje de depuración')
# logging.info('Este es un mensaje informativo')
# logging.warning('Este es un mensaje de advertencia')
# logging.error('Este es un mensaje de error')
# logging.critical('Este es un mensaje crítico')
# ```
#
# En este ejemplo, `basicConfig` configura el logger raíz para mostrar mensajes `INFO` o de nivel superior en la consola, incluyendo la fecha/hora, el nivel de severidad y el mensaje.

# %%
import logging

# Configuración: mensajes a un archivo 'filename' y 'filemode'
# filemode='a' (append) agrega mensajes al final; 'w' (write) sobrescribe el archivo cada vez.
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename='app_registro.log',
    filemode='a',
    encoding='utf-8'
)

logging.info('--- Inicio de una nueva ejecución ---')
logging.info('Aplicación iniciada exitosamente.')

nombre_usuario = 'Juan'
logging.info(f'Usuario {nombre_usuario} ha iniciado sesión.')

def procesar_datos(data):
    if not data:
        logging.warning('Lista de datos vacía proporcionada.')
        return []
    try:
        resultado = [item + 2 for item in data]
        logging.debug('Datos procesados correctamente.')
        return resultado
    except TypeError as e:
        # exc_info=True - guarda el Traceback completo en el archivo
        logging.error(f'Error al procesar datos: {e}', exc_info=True)
        return []

# Pruebas
procesar_datos([])
procesar_datos([1, 2, 3])
procesar_datos([1, 'a', 3])

print("Proceso finalizado. Revisa el archivo 'app_registro.log'")
# Out:
# WARNING:root:Lista de datos vacía proporcionada.
# ERROR:root:Error al procesar datos: can only concatenate str (not "int") to str
# Traceback (most recent call last):
#   File "/tmp/ipykernel_15315/3537246205.py", line 19, in procesar_datos
#     resultado = [item + 2 for item in data]
#                  ~~~~~^~~
# TypeError: can only concatenate str (not "int") to str
# []

# %% [markdown]
# ### Ejercicio 1: Manejo Básico de `try-except`
#
# **Descripción:** Escribe un programa que pida al usuario dos números y realice una división. Maneja la excepción `ZeroDivisionError` en caso de que el segundo número sea cero, mostrando un mensaje adecuado al usuario. También, asegúrate de que si el usuario introduce texto en lugar de números, se maneje la excepción `ValueError`.

# %%
# Escribe tu solución aquí

# %% [markdown]
# ### Ejercicio 2: Uso de `raise` para excepciones personalizadas
#
# **Descripción:** Crea una función llamada `verificar_edad` que reciba un número entero `edad`. Si la edad es menor de 0 o mayor de 120, la función debe lanzar (raise) una excepción `ValueError` con un mensaje descriptivo. Prueba la función con diferentes valores y maneja la excepción con `try-except`.

# %%
# Escribe tu solución aquí

# %% [markdown]
# ### Ejercicio 3: Uso de `assert`
#
# **Descripción:** Escribe una función llamada `calcular_descuento` que reciba un `precio` y un `porcentaje_descuento`. Usa la sentencia `assert` para asegurar que el `precio` sea un número positivo y que el `porcentaje_descuento` esté entre 0 y 100 (ambos inclusive). La función debe devolver el precio final después de aplicar el descuento.

# %%
# Escribe tu solución aquí

# %% [markdown]
# ### Ejercicio 4: Logging en una aplicación simple
#
# **Descripción:** Modifica la función `procesar_datos` del ejemplo anterior para que registre los siguientes eventos:
# - Un mensaje `INFO` cuando la función empieza a ejecutarse.
# - Un mensaje `DEBUG` cuando los datos se procesan correctamente.
# - Un mensaje `WARNING` si la lista de datos está vacía.
# - Un mensaje `ERROR` si ocurre un `TypeError` durante el procesamiento, incluyendo la información de la excepción.

# %%
### Ejercicio 1: Manejo Básico de `try-except`
**Descripción:** Escribe un programa que pida al usuario dos números y realice una división. Maneja la excepción `ZeroDivisionError` en caso de que el segundo número sea cero, mostrando un mensaje adecuado al usuario. También, asegúrate de que si el usuario introduce texto en lugar de números, se maneje la excepción `ValueError`.

def division_segura():
try:
num1 = float(input("Primer número: "))
num2 = float(input("Segundo número: "))
resultado = num1 / num2
print(f"Resultado: {resultado}")
except ZeroDivisionError:
print(" Error: No se puede dividir por cero")
except ValueError:
print(" Error: Debes ingresar números válidos")
except Exception as e:
print(f" Error inesperado: {e}")

# Prueba
division_segura()

### Ejercicio 2: Uso de `raise` para excepciones personalizadas
**Descripción:** Crea una función llamada `verificar_edad` que reciba un número entero `edad`. Si la edad es menor de 0 o mayor de 120, la función debe lanzar (raise) una excepción `ValueError` con un mensaje descriptivo. Prueba la función con diferentes valores y maneja la excepción con `try-except`.

def verificar_edad(edad):
if edad < 0 or edad > 120:
raise ValueError(f"Edad {edad} inválida. Debe estar entre 0 y 120")
return f"Edad {edad} verificada correctamente"

# Prueba con manejo de error
try:
print(verificar_edad(25)) #  Funciona
print(verificar_edad(150)) #  Lanza error
except ValueError as e:
print(f"Error: {e}")



### Ejercicio 3: Uso de `assert`
**Descripción:** Escribe una función llamada `calcular_descuento` que reciba un `precio` y un `porcentaje_descuento`. Usa la sentencia `assert` para asegurar que el `precio` sea un número positivo y que el `porcentaje_descuento` esté entre 0 y 100 (ambos inclusive). La función debe devolver el precio final después de aplicar el descuento.

def calcular_descuento(precio, porcentaje_descuento):
assert precio > 0, f"Precio {precio} debe ser positivo"
assert 0 <= porcentaje_descuento <= 100, f"Porcentaje {porcentaje_descuento} debe estar entre 0 y 100"

descuento = precio * (porcentaje_descuento / 100)
precio_final = precio - descuento
return precio_final

# Pruebas
print(calcular_descuento(100, 20)) # 80.0
print(calcular_descuento(50, 10)) # 45.0

# Esto fallará con AssertionError
# print(calcular_descuento(-10, 50))

### Ejercicio 4: Logging en una aplicación simple
**Descripción:** Modifica la función `procesar_datos` del ejemplo anterior para que registre los siguientes eventos:- Un mensaje `INFO` cuando la función empieza a ejecutarse.- Un mensaje `DEBUG` cuando los datos se procesan correctamente.- Un mensaje `WARNING` si la lista de datos está vacía.- Un mensaje `ERROR` si ocurre un `TypeError` durante el procesamiento, incluyendo la información de la excepción.



import logging
from datetime import datetime

# Configuración simple para guardar errores
logging.basicConfig(
filename='errores.log',
level=logging.ERROR,
format='%(asctime)s - %(message)s'
)

def procesar_datos(data):
print(f"[INFO] Procesando datos: {data}")

if not data:
print("[WARNING] Lista vacía")
return []

try:
resultado = [item + 2 for item in data]
print(f"[DEBUG] Procesado correctamente: {resultado}")
return resultado
except TypeError as e:
# Guardar en archivo de log
logging.error(f"Error en procesar_datos con {data}: {e}")
print(f"[ERROR] Tipo de dato incorrecto: {e}")
return []

# Pruebas
procesar_datos([]) # Warning
procesar_datos([1, 2, 3]) # OK
procesar_datos([1, 'a', 3]) # Error (guarda en errores.log)

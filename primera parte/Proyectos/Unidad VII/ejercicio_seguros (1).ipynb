# %% [markdown]
# # Ejercicio: Análisis de Datos de Seguros Médicos
#
# En este ejercicio vas a trabajar con un dataset real de una aseguradora de salud de Estados Unidos.
# El objetivo es aplicar **todos los conceptos de Pandas** que vimos en clase para analizar el comportamiento de los clientes y los factores que influyen en sus gastos médicos.
#
# ---
#
# ## Descripción del dataset
#
# Las columnas del DataFrame significan lo siguiente:
#
# | Columna | Descripción |
# |--------|-------------|
# | `age` | Edad del cliente |
# | `sex` | Sexo del cliente |
# | `bmi` | Índice de masa corporal (ideal entre 18.5 y 24.9) |
# | `children` | Número de hijos incluidos en el seguro |
# | `smoker` | Si el cliente es fumador o no |
# | `region` | Región donde vive el cliente en USA |
# | `charges` | Gastos médicos individuales facturados por el seguro |
#
# ---
#
# ## Carga de datos
#
# Cargá el archivo CSV desde la siguiente url:
#
# url: `https://drive.google.com/uc?export=download&id=1leo0WjSbpwWOSTMUmCSMPsch3VindqYe`
#
#  y asigná el DataFrame a la variable `df`.

# %%
import pandas as pd
import numpy as np

url='https://drive.google.com/uc?export=download&id=1leo0WjSbpwWOSTMUmCSMPsch3VindqYe'
# crear el dataframe
df = pd.read_csv(url)

# %% [markdown]
# ---
#
# ## PARTE 1 — Exploración inicial del DataFrame
#
# Antes de analizar datos, siempre hay que conocer con qué estamos trabajando.

# %% [markdown]
# **Ejercicio 1.1** — Usá el método apropiado para obtener información general del DataFrame: número de filas, columnas, tipos de datos y valores nulos.

# %%
# Tu código 
df.info()
df.share()
df.dtypes()

# %% [markdown]
# **Ejercicio 1.2** — ¿Cuántas filas y columnas tiene el DataFrame? Guardá el resultado en variables llamadas `n_filas` y `n_columnas` e imprimí un mensaje que diga:
# `"El dataset tiene X filas y Y columnas"`

# %%
# Tu código aquí
n_filas = df.describe()
print(n_filas)

# %% [markdown]
# **Ejercicio 1.3** — Mostrá las primeras 5 filas y las últimas 5 filas del DataFrame.

# %%
# Primeras 5 filas
df.head()

# %%
# Últimas 5 filas
df.tall()

# %% [markdown]
# **Ejercicio 1.4** — Mostrá el tipo de dato de cada columna. ¿Hay algún tipo de dato que te llame la atención? Comentalo en una celda de texto.

# %%
# Tu código aquí
df.dtype()

# %% [markdown]
# *Tu observación aquí:*

# %% [markdown]
# ---
#
# ## PARTE 2 — Estadísticas descriptivas
#
# Usá los métodos de resumen para entender la distribución de los datos.

# %% [markdown]
# **Ejercicio 2.1** — Obtené un resumen estadístico completo de **todas las columnas numéricas** del DataFrame.

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 2.2** — Calculá por separado la **media**, el **mínimo** y el **máximo** de la columna `charges` (gastos médicos). Imprimí los tres resultados con un mensaje descriptivo.

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 2.3** — ¿Cuántos clientes hay por cada región? Usá el método adecuado para contar las repeticiones de cada valor en la columna `region`.

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 2.4** — ¿Cuántos clientes son fumadores y cuántos no? Usá el mismo método sobre la columna `smoker`.

# %%
# Tu código aquí

# %% [markdown]
# ---
#
# ## PARTE 3 — Acceso y selección de datos
#
# Practicá el acceso a filas y columnas con `iloc`, `loc` y selección por nombre.

# %% [markdown]
# **Ejercicio 3.1** — Mostrá **solo las columnas** `age`, `bmi` y `charges` de todo el DataFrame.

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 3.2** — Accedé al **elemento** que se encuentra en la fila de posición 10 y la columna `charges` usando `iloc`.

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 3.3** — Usando `loc`, seleccioná las filas de la 0 a la 4 (inclusive) y las columnas `age`, `sex`, `smoker` y `charges`.

# %%
# Tu código aquí

# %% [markdown]
# ---
#
# ## PARTE 4 — Operaciones y nuevas columnas
#
# Vamos a enriquecer el DataFrame creando columnas nuevas a partir de las existentes.

# %% [markdown]
# **Ejercicio 4.1** — Creá una nueva columna llamada `bmi_category` que clasifique a cada cliente según su BMI:
#
# - `"Bajo peso"` si `bmi < 18.5`
# - `"Normal"` si `18.5 <= bmi <= 24.9`
# - `"Sobrepeso"` si `25 <= bmi <= 29.9`
# - `"Obesidad"` si `bmi >= 30`
#
# *Pista: podés usar `.apply()` o  `pd.cut()` o Resolver de ambas formas y justificar cual es mejor.*

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 4.2**  — Mostrá cuántos clientes hay en cada categoría bmi_category

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 4.3** — Creá una nueva columna llamada `charges_per_child` que represente cuánto paga el cliente por cada hijo en el seguro.
# Para los clientes **sin hijos**, el valor debe ser `NaN` (recordá: dividir entre 0 no tiene sentido).
#
# *Pista: Aunque podrías resolver este ejercicio usando .apply(lambda...), en la práctica profesional se prefiere np.where().*

# %%
# Tu código aquí

# %% [markdown]
# ---
#
# ## PARTE 5 — Filtrado de datos
#
# Aplicá condiciones para seleccionar subconjuntos del DataFrame.

# %% [markdown]
# **Ejercicio 5.1** — Filtrá los clientes que son **fumadores**. ¿Cuántos hay?

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 5.2** — Filtrá los clientes que son **fumadores Y tienen obesidad** (BMI >= 30). Mostrá solo las columnas `age`, `sex`, `bmi`, `smoker` y `charges`.

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 5.3** — Filtrá los clientes de la región `'southeast'` que tienen **más de 2 hijos** y cuyos gastos médicos superan los **$15,000**.

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 5.4** — ¿Cuál es el gasto médico promedio de los clientes **no fumadores**? ¿Y el de los **fumadores**?
# Imprimí ambos valores con un mensaje descriptivo.

# %%
# Tu código aquí

# %% [markdown]
# ---
#
# ## PARTE 6 — Ordenamiento
#
# Ordená el DataFrame para encontrar los casos más relevantes.

# %% [markdown]
# **Ejercicio 6.1** — Mostrá los **10 clientes con mayores gastos médicos**, ordenados de mayor a menor. Mostrá solo `age`, `sex`, `bmi`, `smoker`, `region` y `charges`.

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 6.2** — Mostrá los **5 clientes más jóvenes** (con menor edad). En caso de empate en edad, ordená por `charges` de menor a mayor.

# %%
# Tu código aquí

# %% [markdown]
# ---
#
# ## PARTE 7 — Agrupaciones con groupby
#
# Usá `groupby` para analizar el comportamiento por grupos.

# %% [markdown]
# **Ejercicio 7.1** — Calculá el **promedio de gastos médicos** agrupado por `smoker`. ¿Qué podés concluir?

# %%
# Tu código aquí

# %% [markdown]
# *Tu conclusión aquí:*

# %% [markdown]
# **Ejercicio 7.2** — Agrupá por `region` y calculá la **media** de `charges` y la **media** de `bmi`. Ordená los resultados por `charges` de mayor a menor.

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 7.3** — Agrupá por `sex` y `smoker` a la vez, y calculá el **promedio** y la **desviación estándar** de `charges`.
# ¿los hombres fumadores gastaran más que las mujeres fumadoras?
#
# *Pista: podés pasarle una lista de columnas al `groupby` y usar `.agg()` con una lista de funciones.*

# %%
# Tu código aquí

# %% [markdown]
# **Ejercicio 7.4** — ¿Cuántos clientes hay en cada combinación de `region` y `smoker`? Usá `groupby` y el método `size()`.
#
# ¿Notás alguna región donde la proporción de fumadores sea llamativamente más alta que en las demás?

# %%
# Tu código aquí

# %% [markdown]
# ---

# %% [markdown]
# ## PARTE 8 — Análisis final integrador

# %% [markdown]
# **Pregunta** — ¿Cuál es el perfil del cliente con mayores gastos médicos?**
# Identificá las características del cliente con el gasto más alto: edad, sexo, BMI, número de hijos, si fuma y región.
#
# *Pista: utiliza idxmax()*

# %%
# Tu código aquí

# %% [markdown]
# *Descripción del perfil:*
